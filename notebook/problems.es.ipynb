# %% [markdown]
# # Ejercicios de probabilidad

# %% [markdown]
# ## Ejercicio 1
#
# Dos dados se lanzan una vez y se observa el total obtenido. Usa una simulación para encontrar la probabilidad estimada de que la puntuación sea mayor a 7 o un número par. Una simulación es una repetición del mismo experimento multiples veces para observar su comportamiento:
#
# - Ejecuta el experimento 1000 veces (lanza 2 dados 1000 veces, y suma el número de ambos dados).
# - Lleva ua cuenta de los números y las veces que la suma fue mayor a 7 o un número par.
# - Divide el número del paso 2 entre el número de iteraciones(1000).

# %%
import random

cantidad_experimentos = 1000
exitos = 0

for _ in range(cantidad_experimentos):
    dado1 = random.randint(1, 6)
    dado2 = random.randint(1, 6)
    suma = dado1 + dado2
    
    # Condición: mayor a 7 O número par
    if suma > 7 or suma % 2 == 0:
        exitos += 1

probabilidad = exitos / cantidad_experimentos
print(f"Probabilidad estimada (Suma > 7 o Par): {probabilidad}")
# Out:
# Probabilidad estimada (Suma > 7 o Par): 0.687

# %% [markdown]
# ## Ejercicio 2
#
# Una caja contiene 10 bolas blancas, 20 bolas rojas y 30 bolas verdes. Si tomamos 5 bolas de la caja reemplazándolas (tomando una bola, anotando el color y luego regresandola a la caja). Queremos saber la probabilidad de:
#
# 1. Tomar 3 blancas y 2 rojas.
# 2. Toas todas del mismo color.
#
# Ejecuta el experimento 1000 veces y calcula las probabilidades que mencionadas.

# %%
# 1 al 10 blancas
# 11 al 30 rojas
# 31 al 60 verdes
bola_extraida = random.randint(1, 60)
cantidad_de_experimentos = 1000
contador_casos_fav_todas_mismo_color = 0
contador_casos_fav_2blancas_2rojas = 0

for experimento in range(cantidad_de_experimentos):

    contador_blancas = 0
    contador_rojas = 0
    contador_verdes = 0
    for i in range(5):
        bola_extraida = random.randint(1, 60)

        if bola_extraida >= 1 and bola_extraida <= 10:
            color = "Blanca"
            contador_blancas += 1
        elif bola_extraida >= 11 and bola_extraida <= 30:
            color = "Roja"
            contador_rojas += 1
        elif bola_extraida >= 31 and bola_extraida <= 60:
            color = "Verde"
            contador_verdes += 1

    if contador_blancas == 3 and contador_rojas == 2:
        contador_casos_fav_2blancas_2rojas += 1

    if contador_blancas == 5 or contador_rojas == 5 or contador_verdes == 5:
        contador_casos_fav_todas_mismo_color += 1

print("Probabilidad de 2blancas y 2 rojas:", contador_casos_fav_2blancas_2rojas/cantidad_de_experimentos)
print("Probabilidad de 5 del mismo color:", contador_casos_fav_todas_mismo_color/cantidad_de_experimentos)
# Out:
# Probabilidad de 2blancas y 2 rojas: 0.001
# Probabilidad de 5 del mismo color: 0.038
